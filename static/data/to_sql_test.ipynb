# %%
import pandas as pd
import sqlite3
from sqlalchemy.ext.automap import automap_base

# %%
df = pd.read_csv("conv_date_data.csv")

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng',
#        'City', 'State', 'Zipcode', 'Temperature(F)'],
#       dtype='object')

# %%
df = df.drop(["Unnamed: 0"], 1)

# %%
df.to_csv("conv_date_data.csv")

# %%
df = df.drop(['time_hour'], 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-416b6c98a46c> in <module>
# ----> 1 df = df.drop(['time_hour'], 1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.dtypes
# Out:
# Severity                   int64
# Start_Time        datetime64[ns]
# Start_Lat                float64
# Start_Lng                float64
# City                      object
# State                     object
# Zipcode                    int64
# Temperature(F)           float64
# dtype: object

# %%
df['Start_Time']= pd.to_datetime(df['Start_Time'])

# %%
df.reset_index()

# %%
df = df.round({'Start_Lat': 6, 'Start_Lng': 6})

# %%
df.to_csv("conv_date_data.csv")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
df.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-482195c7ff1f> in <module>
# ----> 1 df.dropna()
#
# AttributeError: 'function' object has no attribute 'dropna'

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-633337079cd0> in <module>
# ----> 1 df.shape
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
# Out:
#          index  Severity          Start_Time  Start_Lat   Start_Lng  \
# 0            0         2 2016-06-21 10:16:00  37.250729 -121.910713
# 1            1         3 2016-06-21 10:17:00  37.328312 -121.871811
# 2            2         2 2016-06-21 11:16:00  38.481682 -121.408768
# 3            3         3 2016-06-21 11:16:00  38.682713 -121.336288
# 4            4         2 2016-06-21 11:37:00  37.775215 -122.220863
# 5            5         3 2016-06-21 11:30:00  37.382370 -121.904358
# 6            6         3 2016-06-21 12:53:00  37.401531 -121.908859
# 7            7         3 2016-06-21 13:02:00  37.825397 -122.304802
# 8            8         3 2016-06-21 13:03:00  37.800900 -122.228767
# 9            9         3 2016-06-21 13:15:00  37.316650 -121.945389
# 10          10         2 2016-06-21 13:23:00  38.618011 -121.401459
# 11          11         3 2016-06-21 14:06:00  37.787350 -122.247955
# 12          12         2 2016-06-21 14:34:00  37.339455 -121.852043
# ...

# %%
conn = sqlite3.connect('accidents.db')
c = conn.cursor()

# %%
c.execute('''
CREATE TABLE accidents 
    (id INT PRIMARY KEY,
    Severity Integer, Start_Time Datetime, Start_Lat DECIMAL(9,6), 
    Start_Lng DECIMAL(9,6),city VARCHAR(15), state VARCHAR(3), zipcode Integer, 
    temperature Decimal)
    ''')

# %%
conn.commit()

# %%
df.to_sql('accidents', conn, if_exists='replace', index = False)
 
c.execute('''  
SELECT * FROM accidents
          ''')

# for row in c.fetchall():
#     print (row)

# %%
c.execute('''  
SELECT * FROM accidents
          ''').fetchall()
# Out:
# [(2,
#   '6/21/16 10:16',
#   37.250729,
#   -121.91071299999999,
#   'San Jose',
#   'CA',
#   95118,
#   75.2),
#  (3,
#   '6/21/16 10:17',
#   37.328312,
#   -121.87181100000001,
#   'San Jose',
#   'CA',
#   95112,
#   73.0),
#  (2, '6/21/16 11:16', 38.481682, -121.408768, 'Sacramento', 'CA', 95828, 86.0),
#  (3,
#   '6/21/16 11:16',
#   38.682713,
#   -121.33628799999998,
#   'Sacramento',
#   'CA',
#   95841,
#   86.0),
#  (2, '6/21/16 11:37', 37.775215, -122.220863, 'Oakland', 'CA', 94601, 73.9),
#  (3, '6/21/16 11:30', 37.38237, -121.904358, 'San Jose', 'CA', 95131, 84.0),
#  (3, '6/21/16 12:53', 37.401531, -121.908859, 'San Jose', 'CA', 95131, 87.1),
#  (3,
#   '6/21/16 13:02',
#   37.825396999999995,
#   -122.304802,
#   'Oakland',
#   'CA',
#   94607,
#   77.0),
#  (3,
#   '6/21/16 13:03',
#   37.8009,
#   -122.22876699999999,
#   'Oakland',
#   'CA',
#   94602,
#   77.0),
#  (3,
#   '6/21/16 13:15',
#   37.31665,
#   -121.94538899999999,
#   'San Jose',
#   'CA',
# ...

# %%
Base.prepare(engine, reflect=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ea32bbf05ec8> in <module>
# ----> 1 Base.prepare(engine, reflect=True)
#
# NameError: name 'engine' is not defined

# %%
Base.classes.keys()
